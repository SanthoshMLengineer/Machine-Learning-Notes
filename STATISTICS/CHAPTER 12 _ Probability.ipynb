# %% [markdown]
# **<h1><center>Probability<center></h1>**
#
# The Probability is represented in a number which tells the chances of getting an event occured. Probability lies between 0 to 1. If Probability Value is near to 1 then there is high chances of getting event occured, if probability value is near to 0 then there is less chance of event occured.
#
#
# Probability is calculted by :
#
#   <center><img src = "https://cdn1.byjus.com/wp-content/uploads/2018/11/formulas/2016/04/07181418/12.jpg"></center>
#
# Some terminologies used in probability :
#
# 1. Sample Space : Total number is events occured in an experiment. Suppose a rolling dice has six possible outcomes. Sample space : {1,2,3,4,5,6}. Also, an event is a subset of Sample Space.
#
# 2. An Event : A subset of the sample space.
#
# 3. Mutually Exclusive Event: When the occurrence of one event prevents the occurrence of other events, then it is said to be a mutually exclusive event.
#
#   P(AUB) = P(A) + P(B)
#
#
# **<h3>Additive Rules of Probability</h3>**
#
# Additive rules state that the probability for getting A or B will be the sum of the probability of getting A and the probability of getting B. It is also denoted by ‘U’.
#
# - If two events are not effected by each other then P(A U B) = P(A) + P(B).
#
# - If two events are affected by each other, then P(A U B) = P(A) + P(B) — P(A ∩ B).
#
#
#
# **<h3>Multiplication Rules of Probability</h3>**
#
# When two events occur one after another here multiplication rules are used. It denotes by the ‘∩’ symbol.
#
# - Two events occur one after another, and both are independent, then the formula for this event is P(A ∩ B) = P(A)*P(B).
#
# - Two events occur one after another, and both are dependent on each other. Then we need to find the probability of occuring first event and find the probability of occuring both event. Then we need to multiply it.
#
#   P(R ∩ K) = P(R)*P(K/R)
#
#   We find a new term, P(K/R), called conditional probability.
#
#
#
# **<h3>Conditional Probability</h3>**
#
# Conditional probability is the probability of an event occurring provided another event has already occurred.
#
# <center><img src = "https://cdn.kastatic.org/googleusercontent/7wjRBuY3NpLE_lQiypt1E2yIQBxqenT6L92UX22pn5hl5IRNAiRj97tLoWjzU2fJkbzJe_RtZ_kFu9g6gEa156Ov" width = "200px"></center>
